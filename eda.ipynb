# %%
import pandas as pd

data = pd.read_csv('datasets\data_after_processing.csv', sep=',')
print(data.head())
# Out:
#    All Time Rank  Spotify Streams  Spotify Playlist Count  \
# 0       0.073859         0.466081                0.515684
# 1       0.498799         0.104109                0.116142
# 2       0.482386         0.259667                0.016499
# 3       0.768415         0.139103                0.158610
# 4       0.529023         0.013209                0.009748
#
#    Spotify Playlist Reach  Spotify Popularity  YouTube Views  YouTube Likes  \
# 0                0.240625            0.831579       0.022376       0.043314
# 1                0.087698            0.747368       0.003997       0.020897
# 2                0.018681            0.536842       0.030744       0.041430
# 3                0.038828            0.726316       0.032441       0.087715
# 4                0.006309            0.333333       0.031307       0.025858
#
#    TikTok Posts  TikTok Likes  TikTok Views  ...  Deezer Playlist Reach  \
# 0      0.017885      0.027770      0.018897  ...               0.002466
# 1      0.005122      0.010741      0.004900  ...               0.000282
# 2      0.223217      0.126402      0.071676  ...               0.002513
# 3      0.010450      0.005866      0.004986  ...               0.001136
# 4      0.120540      0.009113      0.013535  ...               0.006235
#
#    Amazon Playlist Count  Explicit Track  Is_Recent                     Track  \
# 0               0.124402             1.0        0.0           Save Your Tears
# 1               0.081340             0.0        0.0                  Memories
# 2               0.035088             0.0        0.0  Chunni Me Perfume Lagawe
# 3               0.100478             0.0        0.0         Legends Never Die
# 4               0.035088             0.0        0.0             Luchï¿½ï¿½ La
#
#                                       Album Name             Artist  \
# 0                                    After Hours         The Weeknd
# 1                                       Memories         Conan Gray
# 2              Chunni Me Perfume Lagawe - Single    Gajendra Gurjar
# 3  Legends Never Die (feat. Against The Current)  League of Legends
# 4                         Luchï¿½ï¿½ La Ley - Si   BoomBoxRepairKit
#
#    Release Date          ISRC Track Score
# 0    2020-03-20  USUG12000658         NaN
# 1    2022-04-15  USUM72204111       545.9
# 2    2022-06-13  INN852200075       538.4
# 3    2017-09-15  QMAF31500062       444.9
# 4    2022-05-20  QZHN62294886       423.3
#
# [5 rows x 24 columns]
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\janbe\AppData\Local\Temp\ipykernel_32804\1515413473.py:3: SyntaxWarning: invalid escape sequence '\d'
#   data = pd.read_csv('datasets\data_after_processing.csv', sep=',')

# %%
import matplotlib.pyplot as plt
import seaborn as sns


numeric_data = data.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(20, 12))
corr_matrix = numeric_data.corr()
sns.heatmap(
    corr_matrix, annot=True, cmap="coolwarm", fmt=".2f",
    linewidths=0.5, linecolor='gray', cbar_kws={"shrink": .8}, square=True
)
plt.title('Correlation Heatmap of Numeric Features', fontsize=18, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.tight_layout()
plt.show()

# %%
import math
numeric_data.drop(columns=['Explicit Track', 'Is_Recent'], inplace=True)



def plot_boxplots(data):
    """
    Function to plot boxplots for each numeric column in the provided DataFrame.
    
    Parameters:
    - data (pd.DataFrame): The input data containing numeric columns for plotting.
    """
    numeric_data = data.select_dtypes(include=['float64', 'int64'])

    num_columns = len(numeric_data.columns)
    num_rows = math.ceil(num_columns / 3)
    fig, axes = plt.subplots(nrows=num_rows, ncols=3, figsize=(20, num_rows * 5))

    axes = axes.flatten()

    palette = sns.color_palette("coolwarm", num_columns)

    for i, column in enumerate(numeric_data.columns):
        sns.boxplot(data=numeric_data[column], ax=axes[i], color=palette[i])
        axes[i].set_title(f'Boxplot of {column}', fontsize=14, weight='bold')
        axes[i].set_xlabel(column, fontsize=12)
        axes[i].set_ylabel('Value')


    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()
    
    
    
plot_boxplots(numeric_data)

# %%
def plot_histograms(data, bins=20):
    """
    Function to plot histograms for each numeric column in the provided DataFrame.
    
    Parameters:
    - data (pd.DataFrame): The input data containing numeric columns for plotting.
    - bins (int): Number of bins for the histograms (default is 20).
    """
    numeric_data = data.select_dtypes(include=['float64', 'int64'])

    num_columns = len(numeric_data.columns)
    num_rows = math.ceil(num_columns / 3)
    fig, axes = plt.subplots(nrows=num_rows, ncols=3, figsize=(20, num_rows * 5))

    axes = axes.flatten()

    palette = sns.color_palette("coolwarm", num_columns)

    for i, column in enumerate(numeric_data.columns):
        sns.histplot(data=numeric_data[column], ax=axes[i], color=palette[i], bins=bins, kde=True)
        axes[i].set_title(f'Histogram of {column}', fontsize=14, weight='bold')
        axes[i].set_xlabel(column, fontsize=12)
        axes[i].set_ylabel('Frequency')

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()



plot_histograms(numeric_data)
